# %% [markdown]
# ```python
# main
# └── dev
#     ├── features
#     │   ├── feature-clases-tablero-miembro1
#     │   ├── feature-disparo-miembro1
#     │   ├── feature-barcos-miembro2
#     │   ├── feature-validacion-barcos-miembro2
#     │   ├── feature-main-loop-miembro3
#     │   ├── feature-turnos-miembro3
#     │   └── feature-maquina-miembro3
#     │
#     ├── fix
#     │   ├── fix-disparo-miembro1
#     │   ├── fix-barcos-miembro2
#     │   └── fix-input-miembro3
#     │
#     └── docs
#         └── docs-readme
# ```

# %% [markdown]
# miembro1 → clases.py
# - feature-clases-tablero-miembro1
# - feature-disparo-miembro1
#
# miembro2 → funciones.py
# - feature-barcos-miembro2
# - feature-validacion-barcos-miembro2
#
# miembro3 → main.py
# - feature-main-loop-miembro3
# - feature-turnos-miembro3
# - feature-maquina-miembro3
#
# todos → variables.py -> Lo decimos al principio entre todos.
#
# Ejemplo de variables:
# ```python
# dimension = 10 # A parte de para crear el tablero, nos sirve para delimitar el tablero y evitar disparos fuera
#                # if 0 <= x < dimension and 0 <= y < dimension: .... para asegurarnos de que la coordenada sea válida
# barcos = {
#     1: 4,  # 4 barcos de tamaño 1
#     2: 3,  # 3 barcos de tamaño 2
#     3: 2,  # 2 barcos de tamaño 3
#     4: 1   # 1 barco de tamaño 4
# }
# # Crear un diccionario de barcos nos sirve para tenerlo de inventario, facilitar la función de colocación sobre el tablero y controlar las vidas
# agua = " "
# barco = "O"
# tocado = "X"
# fallo = "-"
# ```
