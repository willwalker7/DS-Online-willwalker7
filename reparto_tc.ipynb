# %% [markdown]
# ```python
# main
# └── dev
#     ├── features
#     │   ├── feature-clases-tablero-miembro1
#     │   ├── feature-disparo-miembro1
#     │   ├── feature-barcos-miembro2
#     │   ├── feature-validacion-barcos-miembro2
#     │   ├── feature-main-loop-miembro3
#     │   ├── feature-turnos-miembro3
#     │   └── feature-maquina-miembro3
#     │
#     ├── fix
#     │   ├── fix-disparo-miembro1
#     │   ├── fix-barcos-miembro2
#     │   └── fix-input-miembro3
#     │
#     └── docs
#         └── docs-readme
# ```

# %% [markdown]
# miembro1 → clases.py
# - feature-clases-tablero-miembro1
#
#         -> creamos la clase tablero, con atributos de jugador, dimensiones, tablero y disparo
#
#         -> añadimos los metodos __init__ y mostrar()
#
# - feature-disparo-miembro1 (parece algo complejo crear una clase disparo)
#
#         -> debemos poder añadir disparar(x,y)
#
#         -> sus funciones serán comprobar si hay barco y marcar si hay impacto o fallo, devolviendo True si hay barco o False si hay agua
#
#         -> importante hacerlo de tal manera que no permita disparar fuera de las dimensiones del tablero
#
#         -> con esto ya podremos disparar
#
# miembro2 → funciones.py
# - feature-barcos-miembro2
#
#         -> el objetivo es colocar los barcos
#
#         -> debe contener la función colocar_barcos(tablero_barcos)
#
#         -> recorre un el diccionario de barcos (tendremos una variable de tipo diccionario llamada barcos que contendrá la cantidad de barcos y la longitud de cada uno)
#
#         -> coloca los barcos usando el elemento que escojamos para marcar los barcos, por ejemplo "O"
#
#         -> con esto podremos colocar barcos sobre los tableros
#
# - feature-validacion-barcos-miembro2
#
#         -> en esta rama trabajamos sobre las condiciones que debe tener la colocación de barcos, para que no se solapen entre si y para que no se salgan edl tablero
#
# miembro3 → main.py
# - feature-main-loop-miembro3
#
#         -> aquí es donde estructuramos el juego con los While True
#
#         -> lanzamos los mensajes iniciales y creamos los tableros
#
# - feature-turnos-miembro3
#
#         -> aqui creamos los turnos del jugador, solicitando cordenadas al jugador y generando tambien coordenadas de los disparos de la máquina
#             -> maquna.disparar(x,y)
#
#         -> determinamos las lógicas de que el que acierta repite, y el que falla pasa el turno al rival
#
#         -> el resultado de este apartado es conseguir un turno funcional del jugador
#
# - feature-maquina-miembro3
#
#         -> en esta parte creamos los turnos automáticos con random.randit(...)
#
#         -> con este apartado conseguiremos que la máquina juegue sola
#
# -> dentro del main.py, de forma implícita deberemos determinar las condiciones para la conclusión del juego con:
#
#         if vidas == 0:
#
#         - > y devolvemos un mensaje al ganador, termiando la partida
#
# todos → variables.py -> Lo decimos al principio entre todos.
#
# Ejemplo de variables:
# ```python
# dimension = 10 # A parte de para crear el tablero, nos sirve para delimitar el tablero y evitar disparos fuera
#                # if 0 <= x < dimension and 0 <= y < dimension: .... para asegurarnos de que la coordenada sea válida
# barcos = {
#     1: 4,  # 4 barcos de tamaño 1
#     2: 3,  # 3 barcos de tamaño 2
#     3: 2,  # 2 barcos de tamaño 3
#     4: 1   # 1 barco de tamaño 4
# }
# # Crear un diccionario de barcos nos sirve para tenerlo de inventario, facilitar la función de colocación sobre el tablero y controlar las vidas
#
# agua = " "
# barco = "O"
# tocado = "X"
# fallo = "-"
# ```
